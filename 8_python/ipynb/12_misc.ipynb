# %%
import os
from time import time
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LinearRegression,LogisticRegression
import re

# %%
RANDOM_STATE =24
np.random.seed(RANDOM_STATE)

NOISE = 0.1
N_SAMPLEs =1000
TEST_SIZE = 0.2
CMAP = plt.cm.rainbow

# %%
iris_df = sns.load_dataset('iris')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
correlation_matrix = iris_df.drop('species',axis=1).corr()
correlation_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm' )
plt.show()

# %%
#pair plot
sns.pairplot(data=iris_df,kind='scatter',hue='species',markers=['o','s','D']);

# %% [markdown]
# # COVARIANCE

# %%
covariance_matrix = iris_df.drop('species',axis=1).cov()
covariance_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
plt.figure()
sns.heatmap(covariance_matrix,annot=True,cmap='coolwarm' )
plt.show()

# %%
boston_file ='/home/dhpcap/1cdac/python/vscode/asp/boston_house_price.csv'
data_df = pd.read_csv(boston_file)
data_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
data_df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
feature_df = data_df.drop('MEDV', axis=1).copy()
labels_df = data_df['MEDV'].to_numpy()

# %%
feature_df.corr()
# Out:
#              CRIM        ZN     INDUS  ...   PTRATIO         B     LSTAT
# CRIM     1.000000 -0.200469  0.406583  ...  0.289946 -0.385064  0.455621
# ZN      -0.200469  1.000000 -0.533828  ... -0.391679  0.175520 -0.412995
# INDUS    0.406583 -0.533828  1.000000  ...  0.383248 -0.356977  0.603800
# CHAS    -0.055892 -0.042697  0.062938  ... -0.121515  0.048788 -0.053929
# NOX      0.420972 -0.516604  0.763651  ...  0.188933 -0.380051  0.590879
# RM      -0.219247  0.311991 -0.391676  ... -0.355501  0.128069 -0.613808
# AGE      0.352734 -0.569537  0.644779  ...  0.261515 -0.273534  0.602339
# DIS     -0.379670  0.664408 -0.708027  ... -0.232471  0.291512 -0.496996
# RAD      0.625505 -0.311948  0.595129  ...  0.464741 -0.444413  0.488676
# TAX      0.582764 -0.314563  0.720760  ...  0.460853 -0.441808  0.543993
# PTRATIO  0.289946 -0.391679  0.383248  ...  1.000000 -0.177383  0.374044
# B       -0.385064  0.175520 -0.356977  ... -0.177383  1.000000 -0.366087
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(data_df.corr().abs(),annot = True,ax=ax)
plt.show()

# %%
data_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
col_sel = ['LSTAT','PTRATIO','RM','TAX','INDUS','NOX']

features_df = data_df[col_sel].copy()

# %% [markdown]
# # LINEAR REGERSSION

# %%
reg = LinearRegression()
reg.fit(feature_df,labels_df)
y_pred = reg.predict(feature_df)

# %%
fig, ax = plt.subplots(figsize=(13,8))
plt.scatter(labels_df,y_pred)
plt.plot([y_pred.min(),y_pred.max()], [labels_df.min(),labels_df.max()], c='r', lw=4);

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
X,y = datasets.make_moons(n_samples=N_SAMPLEs,noise=NOISE,random_state=RANDOM_STATE)

# %%
fig, ax = plt.subplots(figsize=(13,8))
plt.scatter(X[:,0],X[:,1],c=y,cmap=CMAP);

# %%
clf = LogisticRegression(penalty=None,random_state=RANDOM_STATE)
clf.fit(X,y)
y_pred=clf.predict(X)
accuracy_score(y_true=y,y_pred=y_pred)
# Out:
# 0.881
