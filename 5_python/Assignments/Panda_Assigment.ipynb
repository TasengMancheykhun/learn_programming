# %%
import pandas as pd

# %% [markdown]
# 1. Write a Pandas program to read a csv file from a specified source and print the
# first 5 rows.
# (Diamonds.csv)

# %%
diamond ='/home/dhpcap/1cdac/python/vscode/asp/diamonds.csv'
data_df = pd.read_csv(diamond)
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# 2. Write a Pandas program to read a dataset from diamonds DataFrame and
# modify the default columns values and print the first 6 rows.

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
user_cols = ['carat', 'cut', 'x', 'y', 'z']
print("First 6 rows:")
print(data_df[user_cols].head(6))
# Out:
# First 6 rows:
#    carat        cut     x     y     z
# 0   0.23      Ideal  3.95  3.98  2.43
# 1   0.21    Premium  3.89  3.84  2.31
# 2   0.23       Good  4.05  4.07  2.31
# 3   0.29    Premium  4.20  4.23  2.63
# 4   0.31       Good  4.34  4.35  2.75
# 5   0.24  Very Good  3.94  3.96  2.48

# %% [markdown]
# 3. Write a Pandas program to select a series from diamonds DataFrame. Print
# the content of the series.

# %%
print(data_df['carat'])
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %% [markdown]
# 4. Write a Pandas program to create a new 'Quality -color' Series (use bracket
# notation to define the Series name) of the diamonds DataFrame.

# %%
data_df['Quality–color'] = data_df.cut + ', ' + data_df.color
print(data_df.head())
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 5. Write a Pandas program to find the number of rows and columns and data
# type of each column of diamonds Dataframe.

# %%
print(f'Number of rows and columns : {data_df.shape}\n')


print("Data Types Of Each Column : \n")
print( data_df.dtypes)
# Out:
# Number of rows and columns : (53940, 12)
#
# Data Types Of Each Column :
#
# Unnamed: 0         int64
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality–color     object
# dtype: object

# %% [markdown]
# 6. Write a Pandas program to summarize only 'object' columns of the diamonds
# Dataframe.

# %%
print("Summarize of 'object' columns:\n")
print(data_df.describe(include=['object']))
# Out:
# Summarize of 'object' columns:
#
#           cut  color clarity Quality–color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1      Ideal, G
# freq    21551  11292   13065          4884

# %% [markdown]
# 7. Write a Pandas program to rename two of the columns of the diamonds
# Dataframe.

# %%
print("Original DATA : ")
print(data_df.head())
print("DATA After renaming price to cost and cut to diamond_cut : ")
a=data_df.rename(columns={'price':'cost','cut':'diamond_cut'},inplace=False)
print(a.head())
# Out:
# Original DATA :
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J
# DATA After renaming price to cost and cut to diamond_cut :
#    Unnamed: 0  carat diamond_cut color clarity  depth  table  cost     x  \
# 0           1   0.23       Ideal     E     SI2   61.5   55.0   326  3.95
# 1           2   0.21     Premium     E     SI1   59.8   61.0   326  3.89
# 2           3   0.23        Good     E     VS1   56.9   65.0   327  4.05
# 3           4   0.29     Premium     I     VS2   62.4   58.0   334  4.20
# 4           5   0.31        Good     J     SI2   63.3   58.0   335  4.34
#
#       y     z Quality–color
# 0  3.98  2.43      Ideal, E
# 1  3.84  2.31    Premium, E
# 2  4.07  2.31       Good, E
# 3  4.23  2.63    Premium, I
# 4  4.35  2.75       Good, J

# %% [markdown]
# 8. Write a Pandas program to rename all the columns of the diamonds
# Dataframe.

# %%
print("DATA After renaming the columns names : ")
new_col = ['new_Unnamed: 0', 'new_carat', 'new_diamond_cut', 'new_color', 'new_clarity', 'new_depth',
       'new_table', 'new_cost', 'new_x', 'new_y', 'new_z', 'new_Quality–color']
a.columns=new_col

print(a.head())
# Out:
# DATA After renaming the columns names :
#    new_Unnamed: 0  new_carat new_diamond_cut new_color new_clarity  new_depth  \
# 0               1       0.23           Ideal         E         SI2       61.5
# 1               2       0.21         Premium         E         SI1       59.8
# 2               3       0.23            Good         E         VS1       56.9
# 3               4       0.29         Premium         I         VS2       62.4
# 4               5       0.31            Good         J         SI2       63.3
#
#    new_table  new_cost  new_x  new_y  new_z new_Quality–color
# 0       55.0       326   3.95   3.98   2.43          Ideal, E
# 1       61.0       326   3.89   3.84   2.31        Premium, E
# 2       65.0       327   4.05   4.07   2.31           Good, E
# 3       58.0       334   4.20   4.23   2.63        Premium, I
# 4       58.0       335   4.34   4.35   2.75           Good, J

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 9. Write a Pandas program to remove the second column of the diamonds
# Dataframe.

# %%
a=data_df.drop('table', axis=1)
a.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  price     x     y     z  \
# 0           1   0.23    Ideal     E     SI2   61.5    326  3.95  3.98  2.43
# 1           2   0.21  Premium     E     SI1   59.8    326  3.89  3.84  2.31
# 2           3   0.23     Good     E     VS1   56.9    327  4.05  4.07  2.31
# 3           4   0.29  Premium     I     VS2   62.4    334  4.20  4.23  2.63
# 4           5   0.31     Good     J     SI2   63.3    335  4.34  4.35  2.75
#
#   Quality–color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# 10. Write a Pandas program to remove multiple columns at once of the diamonds
# Dataframe.

# %%
print("\nAfter removing multiple columns:")
a=data_df.drop(['cut', 'color', 'y'], axis=1, inplace=False)
a.head()
# Out:
# After removing multiple columns:
#    Unnamed: 0  carat clarity  depth  table  price     x     z Quality–color
# 0           1   0.23     SI2   61.5   55.0    326  3.95  2.43      Ideal, E
# 1           2   0.21     SI1   59.8   61.0    326  3.89  2.31    Premium, E
# 2           3   0.23     VS1   56.9   65.0    327  4.05  2.31       Good, E
# 3           4   0.29     VS2   62.4   58.0    334  4.20  2.63    Premium, I
# 4           5   0.31     SI2   63.3   58.0    335  4.34  2.75       Good, J

# %% [markdown]
# 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to
# rows) from diamonds dataframe.

# %%
print("\nAfter removing multiple Rows :")
a=data_df.drop([1,2,3], axis=0, inplace=False)
a.head()
# Out:
# After removing multiple Rows :
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
#
#       y     z Quality–color
# 0  3.98  2.43      Ideal, E
# 4  4.35  2.75       Good, J
# 5  3.96  2.48  Very Good, J
# 6  3.98  2.47  Very Good, I
# 7  4.11  2.53  Very Good, H

# %% [markdown]
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a
# Series) of diamonds Dataframe.

# %%
print("\ncut Series in ascending order :")
a=data_df.cut.sort_values(ascending=True)
a.head(20)
# Out:
# cut Series in ascending order :
# 3850     Fair
# 51464    Fair
# 51466    Fair
# 10237    Fair
# 10760    Fair
# 14645    Fair
# 13271    Fair
# 13270    Fair
# 22871    Fair
# 7586     Fair
# 49235    Fair
# 18337    Fair
# 2948     Fair
# 51463    Fair
# 51495    Fair
# 51497    Fair
# 1469     Fair
# 24490    Fair
# 45442    Fair
# 22852    Fair
# Name: cut, dtype: object

# %% [markdown]
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns
# a Series) of diamonds Dataframe.

# %%
print("\ncut Series in descending order :")
a=data_df.price.sort_values(ascending=False)
a
# Out:
# cut Series in descending order :
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat'
# Series in ascending and descending order.

# %%
print("\nSort the entire diamonds DataFrame by the 'carat' Series in ascending order\n")
result = data_df.sort_values('carat')
print(result)
print("\nSort the entire diamonds DataFrame by the 'carat' Series in descending  order\n")
result = data_df.sort_values('carat', ascending=False)
print(result)
# Out:
# Sort the entire diamonds DataFrame by the 'carat' Series in ascending order
#
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345   3.79
# 31598       31599   0.20  Very Good     E     VS2   63.4   59.0    367   3.74
# 31600       31601   0.20    Premium     D     VS2   62.3   60.0    367   3.73
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367   3.79
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 25999       26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14
# 27130       27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z Quality–color
# 14      3.75  2.27    Premium, E
# 31598   3.71  2.36  Very Good, E
# 31600   3.68  2.31    Premium, D
# 31591   3.77  2.26    Premium, E
# 31592   3.78  2.24    Premium, E
# ...      ...   ...           ...
# 25999   9.94  6.24    Premium, J
# 25998  10.10  6.17    Premium, I
# 27130   9.85  6.43       Fair, H
# 27630  10.16  6.72       Fair, J
# 27415  10.54  6.98       Fair, J
#
# [53940 rows x 12 columns]
#
# Sort the entire diamonds DataFrame by the 'carat' Series in descending  order
#
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 27415       27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74
# 27630       27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23
# 27130       27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00
# 25999       26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 31596       31597   0.20    Premium     F     VS2   62.6   59.0    367   3.73
# 31599       31600   0.20      Ideal     E     VS2   62.2   57.0    367   3.76
# 31598       31599   0.20  Very Good     E     VS2   63.4   59.0    367   3.74
# 31597       31598   0.20      Ideal     D     VS2   61.5   57.0    367   3.81
# 31600       31601   0.20    Premium     D     VS2   62.3   60.0    367   3.73
#
#            y     z Quality–color
# 27415  10.54  6.98       Fair, J
# 27630  10.16  6.72       Fair, J
# 27130   9.85  6.43       Fair, H
# 25999   9.94  6.24    Premium, J
# 25998  10.10  6.17    Premium, I
# ...      ...   ...           ...
# 31596   3.71  2.33    Premium, F
# 31599   3.73  2.33      Ideal, E
# 31598   3.71  2.36  Very Good, E
# 31597   3.77  2.33      Ideal, D
# 31600   3.68  2.31    Premium, D
#
# [53940 rows x 12 columns]

# %% [markdown]
# 15. Write a Pandas program to filter the DataFrame rows to only show carat
# weight at least 0.3.

# %%
print("\nRows to only show carat weight at least 0.3:")
filtered_data_df = data_df[data_df['carat'] >= 0.3]
filtered_data_df.head(10)
# Out:
# Rows to only show carat weight at least 0.3:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 13          14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15          16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16          17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# 17          18   0.30       Good     J     SI1   63.4   54.0    351  4.23
# 18          19   0.30       Good     J     SI1   63.8   56.0    351  4.23
# 19          20   0.30  Very Good     J     SI1   62.7   59.0    351  4.21
# 20          21   0.30       Good     I     SI2   63.3   56.0    351  4.26
# 23          24   0.31  Very Good     J     SI1   59.4   62.0    353  4.39
#
#        y     z Quality–color
# 4   4.35  2.75       Good, J
# 10  4.28  2.73       Good, J
# 13  4.37  2.71      Ideal, J
# 15  4.42  2.68    Premium, E
# 16  4.34  2.68      Ideal, I
# 17  4.29  2.70       Good, J
# 18  4.26  2.71       Good, J
# 19  4.27  2.66  Very Good, J
# 20  4.30  2.71       Good, I
# 23  4.43  2.62  Very Good, J

# %% [markdown]
# 16. Write a Pandas program to convert a python list to pandas series.

# %%
name_list=['hYd','cdac','pune','pashan']
print("Original list:")
print(name_list)
print("Convert the list to a Series:")

panda_series = pd.Series(name_list)
print(panda_series)
# Out:
# Original list:
# ['hYd', 'cdac', 'pune', 'pashan']
# Convert the list to a Series:
# 0       hYd
# 1      cdac
# 2      pune
# 3    pashan
# dtype: object

# %% [markdown]
# 17. Write a Pandas program to find the details of the diamonds where length>5,
# width>5 and depth>5.

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %%
print("\nRows to only show carat weight at least 0.3:")
filtered_data_df = data_df[(data_df.x>5) & (data_df.y>5) & (data_df.z>5)]
filtered_data_df.head(10)
# Out:
# Rows to only show carat weight at least 0.3:
#        Unnamed: 0  carat   cut color clarity  depth  table  price     x     y  \
# 11778       11779   1.83  Fair     J      I1   70.0   58.0   5083  7.34  7.28
# 13002       13003   2.14  Fair     J      I1   69.4   57.0   5405  7.74  7.70
# 13118       13119   2.15  Fair     J      I1   65.5   57.0   5430  8.01  7.95
# 13562       13563   1.96  Fair     F      I1   66.6   60.0   5554  7.59  7.56
# 13757       13758   2.22  Fair     J      I1   66.7   56.0   5607  8.04  8.02
# 13929       13930   2.00  Fair     I      I1   66.0   60.0   5667  7.78  7.74
# 13991       13992   2.01  Fair     I      I1   67.4   58.0   5696  7.71  7.64
# 14138       14139   2.27  Fair     J      I1   67.6   55.0   5733  8.05  8.00
# 14504       14505   1.81  Fair     J      I1   68.0   57.0   5859  7.43  7.39
# 14645       14646   2.00  Fair     H      I1   69.8   54.0   5914  7.60  7.56
#
#           z Quality–color
# 11778  5.12       Fair, J
# 13002  5.36       Fair, J
# 13118  5.23       Fair, J
# 13562  5.04       Fair, F
# 13757  5.36       Fair, J
# 13929  5.10       Fair, I
# 13991  5.17       Fair, I
# 14138  5.43       Fair, J
# 14504  5.04       Fair, J
# 14645  5.29       Fair, H

# %% [markdown]
# 18. Write a Pandas program to find the diamonds that are either Premium or
# Ideal.

# %%
print("\nThe diamonds that are either Premium or Ideal : ")
filtered_data_df = data_df[(data_df['cut']=='Premium') |(data_df['cut']=='Ideal')]
filtered_data_df.head(10)
# Out:
# The diamonds that are either Premium or Ideal :
#     Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0            1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1            2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3            4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 11          12   0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90
# 12          13   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84
# 13          14   0.31    Ideal     J     SI2   62.2   54.0    344  4.35  4.37
# 14          15   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75
# 15          16   0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42
# 16          17   0.30    Ideal     I     SI2   62.0   54.0    348  4.31  4.34
# 26          27   0.24  Premium     I     VS1   62.5   57.0    355  3.97  3.94
#
#        z Quality–color
# 0   2.43      Ideal, E
# 1   2.31    Premium, E
# 3   2.63    Premium, I
# 11  2.46      Ideal, J
# 12  2.33    Premium, F
# 13  2.71      Ideal, J
# 14  2.27    Premium, E
# 15  2.68    Premium, E
# 16  2.68      Ideal, I
# 26  2.47    Premium, I

# %% [markdown]
# 19. Write a Pandas program to find the diamonds that are with a Fair or Good or
# Premium.

# %%
print("\nThe diamonds that are with a Fair or Good or Premium:")
filtered_data_df = data_df[(data_df['cut']=='Premium') |(data_df['cut']=='Fair')|(data_df['cut']=='Good')]
filtered_data_df.head(10)
# Out:
# The diamonds that are with a Fair or Good or Premium:
#     Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 1            2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2            3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3            4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4            5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
# 8            9   0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78
# 10          11   0.30     Good     J     SI1   64.0   55.0    339  4.25  4.28
# 12          13   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84
# 14          15   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75
# 15          16   0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42
# 17          18   0.30     Good     J     SI1   63.4   54.0    351  4.23  4.29
#
#        z Quality–color
# 1   2.31    Premium, E
# 2   2.31       Good, E
# 3   2.63    Premium, I
# 4   2.75       Good, J
# 8   2.49       Fair, E
# 10  2.73       Good, J
# 12  2.33    Premium, F
# 14  2.27    Premium, E
# 15  2.68    Premium, E
# 17  2.70       Good, J

# %% [markdown]
# 20. Write a Pandas program to display all column labels of diamonds DataFrame.

# %%
print(data_df.columns)
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z', 'Quality–color'],
#       dtype='object')

# %% [markdown]
# 21. Write a Pandas program to read only a subset of 3 rows from diamonds
# DataFrame.

# %%
print("\nSubset of 3 rows from diamonds DataFrame:")
result = pd.read_csv(diamond, nrows=3)
print(result.head())
# Out:
# Subset of 3 rows from diamonds DataFrame:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9     65    327  4.05  4.07
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31

# %% [markdown]
# 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
print("\nIterate through diamonds DataFrame:")
for index, row in data_df.iterrows():
   print(f'index :{index}, carat: {row.carat}, cut : {row.cut}')
# Out:
# Iterate through diamonds DataFrame:
# index :0, carat: 0.23, cut : Ideal
# index :1, carat: 0.21, cut : Premium
# index :2, carat: 0.23, cut : Good
# index :3, carat: 0.29, cut : Premium
# index :4, carat: 0.31, cut : Good
# index :5, carat: 0.24, cut : Very Good
# index :6, carat: 0.24, cut : Very Good
# index :7, carat: 0.26, cut : Very Good
# index :8, carat: 0.22, cut : Fair
# index :9, carat: 0.23, cut : Very Good
# index :10, carat: 0.3, cut : Good
# index :11, carat: 0.23, cut : Ideal
# index :12, carat: 0.22, cut : Premium
# index :13, carat: 0.31, cut : Ideal
# index :14, carat: 0.2, cut : Premium
# index :15, carat: 0.32, cut : Premium
# index :16, carat: 0.3, cut : Ideal
# index :17, carat: 0.3, cut : Good
# index :18, carat: 0.3, cut : Good
# index :19, carat: 0.3, cut : Very Good
# index :20, carat: 0.3, cut : Good
# index :21, carat: 0.23, cut : Very Good
# index :22, carat: 0.23, cut : Very Good
# index :23, carat: 0.31, cut : Very Good
# index :24, carat: 0.31, cut : Very Good
# index :25, carat: 0.23, cut : Very Good
# index :26, carat: 0.24, cut : Premium
# index :27, carat: 0.3, cut : Very Good
# index :28, carat: 0.23, cut : Very Good
# index :29, carat: 0.23, cut : Very Good
# index :30, carat: 0.23, cut : Very Good
# index :31, carat: 0.23, cut : Very Good
# index :53912, carat: 0.61, cut : Premium
# index :53913, carat: 0.8, cut : Good
# index :53914, carat: 0.84, cut : Good
# index :53915, carat: 0.77, cut : Ideal
# index :53916, carat: 0.74, cut : Good
# index :53917, carat: 0.9, cut : Very Good
# index :53918, carat: 0.76, cut : Premium
# index :53919, carat: 0.76, cut : Ideal
# index :53920, carat: 0.7, cut : Very Good
# index :53921, carat: 0.7, cut : Very Good
# index :53922, carat: 0.7, cut : Very Good
# index :53923, carat: 0.73, cut : Ideal
# index :53924, carat: 0.73, cut : Ideal
# index :53925, carat: 0.79, cut : Ideal
# index :53926, carat: 0.71, cut : Ideal
# index :53927, carat: 0.79, cut : Good
# index :53928, carat: 0.79, cut : Premium
# index :53929, carat: 0.71, cut : Ideal
# index :53930, carat: 0.71, cut : Premium
# index :53931, carat: 0.71, cut : Premium
# index :53932, carat: 0.7, cut : Very Good
# index :53933, carat: 0.7, cut : Very Good
# index :53934, carat: 0.72, cut : Premium
# index :53935, carat: 0.72, cut : Ideal
# index :53936, carat: 0.72, cut : Good
# index :53937, carat: 0.7, cut : Very Good
# index :53938, carat: 0.86, cut : Premium
# index :53939, carat: 0.75, cut : Ideal

# %% [markdown]
# 23. Write a Pandas program to drop all non-numeric columns from diamonds
# DataFrame.

# %%
num_col=['Unnamed: 0', 'carat', 'depth', 'table', 'price', 'x', 'y', 'z']

cat_col=['cut', 'color', 'clarity', 'Quality–color' ]

a=data_df.drop(columns=num_col, axis=1, inplace=False)
a.head()
# Out:
#        cut color clarity Quality–color
# 0    Ideal     E     SI2      Ideal, E
# 1  Premium     E     SI1    Premium, E
# 2     Good     E     VS1       Good, E
# 3  Premium     I     VS2    Premium, I
# 4     Good     J     SI2       Good, J

# %% [markdown]
# 24. Write a Pandas program to include only numeric columns in the diamonds
# DataFrame.

# %%
import numpy as np
a=data_df.select_dtypes(include=[np.number]).dtypes
a.head()
# Out:
# Unnamed: 0      int64
# carat         float64
# depth         float64
# table         float64
# price           int64
# dtype: object

# %%
a=data_df.drop(columns=cat_col, axis=1, inplace=False)
a.head()
# Out:
#    Unnamed: 0  carat  depth  table  price     x     y     z
# 0           1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1           2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2           3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3           4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4           5   0.31   63.3   58.0    335  4.34  4.35  2.75

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53940 non-null  int64
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   color          53940 non-null  object
#  4   clarity        53940 non-null  object
#  5   depth          53940 non-null  float64
#  6   table          53940 non-null  float64
#  7   price          53940 non-null  int64
#  8   x              53940 non-null  float64
#  9   y              53940 non-null  float64
#  10  z              53940 non-null  float64
#  11  Quality–color  53940 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 4.9+ MB

# %% [markdown]
# 25. Write a Pandas program to pass a list of data types to only describe certain
# types of diamonds DataFrame.

# %%
data_df.describe(include=['int64'])   #describing only 'int64' data type
# Out:
#          Unnamed: 0         price
# count  53940.000000  53940.000000
# mean   26970.500000   3932.799722
# std    15571.281097   3989.439738
# min        1.000000    326.000000
# 25%    13485.750000    950.000000
# 50%    26970.500000   2401.000000
# 75%    40455.250000   5324.250000
# max    53940.000000  18823.000000

# %%
data_df.describe(include=['float64'])    #describing only 'float64' data type
# Out:
#               carat         depth         table             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184      5.731157      5.734526
# std        0.474011      1.432621      2.234491      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
data_df.describe(include=['object'])       #describing only 'object' data type
# Out:
#           cut  color clarity Quality–color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1      Ideal, G
# freq    21551  11292   13065          4884

# %% [markdown]
# 26. Write a Pandas program to calculate the mean of each numeric column of
# diamonds DataFrame.

# %%
data_df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
a = data_df[num_col].mean(axis=0)
a.head()
# Out:
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# dtype: float64

# %% [markdown]
# 27. Write a Pandas program to calculate the mean of each row of diamonds
# DataFrame.

# %%
a=data_df[num_col].mean(axis=1)
a.head(10)
# Out:
# 0    56.76125
# 1    57.38125
# 2    57.82000
# 3    58.71875
# 4    59.13125
# 5    59.05250
# 6    59.11750
# 7    59.10875
# 8    60.30750
# 9    59.88375
# dtype: float64

# %% [markdown]
# 28. Write a Pandas program to calculate the mean of price for each cut of
# diamonds DataFrame.

# %%
a=data_df[['cut','price']].groupby(['cut']).mean()
print(a)
# Out:
#                  price
# cut
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
data_df.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# 29. Write a Pandas program to calculate count, minimum, maximum price for
# each cut of diamonds DataFrame.

# %%
data_df.groupby('cut').price.describe()
# Out:
#              count         mean          std    min      25%     50%      75%  \
# cut
# Fair        1610.0  4358.757764  3560.386612  337.0  2050.25  3282.0  5205.50
# Good        4906.0  3928.864452  3681.589584  327.0  1145.00  3050.5  5028.00
# Ideal      21551.0  3457.541970  3808.401172  326.0   878.00  1810.0  4678.50
# Premium    13791.0  4584.257704  4349.204961  326.0  1046.00  3185.0  6296.00
# Very Good  12082.0  3981.759891  3935.862161  336.0   912.00  2648.0  5372.75
#
#                max
# cut
# Fair       18574.0
# Good       18788.0
# Ideal      18806.0
# Premium    18823.0
# Very Good  18818.0

# %% [markdown]
# 30. Write a Pandas program to create a side-by-side bar plot of the diamonds
# DataFrame.

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %%
cat_col
# Out:
# ['cut', 'color', 'clarity', 'Quality–color']

# %%
import matplotlib.pyplot as plt

for col in cat_col:
    data_df.groupby(col).price.mean().plot(kind='bar')
    plt.show()

# %% [markdown]
# 31. Write a Pandas program to count how many times each value in cut series of
# diamonds DataFrame occurs.

# %%
data_df['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# 32. Write a Pandas program to display percentages of each value of cut series
# occurs in diamonds DataFrame.

# %%
data_df.cut.value_counts(normalize=True)
# Out:
# cut
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: proportion, dtype: float64

# %% [markdown]
# 33. Write a Pandas program to display the unique values in cut series of
# diamonds DataFrame.

# %%
data_df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# 34. Write a Pandas program to count the number of unique values in cut series of
# diamonds DataFrame.

# %%
data_df.cut.nunique()
# Out:
# 5

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 35. Write a Pandas program to compute a cross-tabulation of two Series in
# diamonds DataFrame.

# %%
pd.crosstab(data_df.cut, data_df.color)
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %% [markdown]
# 36. Write a Pandas program to calculate various summary statistics of cut series
# of diamonds DataFrame.

# %%
data_df['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 37. Write a Pandas program to create a histogram of the 'carat' Series
# (distribution of a numerical variable) of diamonds DataFrame.

# %%
data_df['carat'].plot(kind='hist', bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut'
# series of diamonds DataFrame.

# %%
data_df.cut.value_counts().plot(kind='bar',color='blue')
# Out:
# <Axes: xlabel='cut'>

# %% [markdown]
# 39. Write a Pandas program to create a DataFrame of booleans (True if missing,
# False if not missing) from diamonds DataFrame.

# %%
a=data_df.isnull()
a.head(10)
# Out:
#    Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0       False  False  False  False    False  False  False  False  False
# 1       False  False  False  False    False  False  False  False  False
# 2       False  False  False  False    False  False  False  False  False
# 3       False  False  False  False    False  False  False  False  False
# 4       False  False  False  False    False  False  False  False  False
# 5       False  False  False  False    False  False  False  False  False
# 6       False  False  False  False    False  False  False  False  False
# 7       False  False  False  False    False  False  False  False  False
# 8       False  False  False  False    False  False  False  False  False
# 9       False  False  False  False    False  False  False  False  False
#
#        y      z  Quality–color
# 0  False  False          False
# 1  False  False          False
# 2  False  False          False
# 3  False  False          False
# 4  False  False          False
# 5  False  False          False
# 6  False  False          False
# 7  False  False          False
# 8  False  False          False
# 9  False  False          False

# %% [markdown]
# 40. Write a Pandas program to count the number of missing values in each
# Series of diamonds DataFrame.

# %%
data_df.columns

for col in data_df.columns:
    a=data_df[col].isnull().sum()
    print(col,"=",a)
    print("------------------------------")
# Out:
# Unnamed: 0 = 0
# ------------------------------
# carat = 0
# ------------------------------
# cut = 0
# ------------------------------
# color = 0
# ------------------------------
# clarity = 0
# ------------------------------
# depth = 0
# ------------------------------
# table = 0
# ------------------------------
# price = 0
# ------------------------------
# x = 0
# ------------------------------
# y = 0
# ------------------------------
# z = 0
# ------------------------------
# Quality–color = 0
# ------------------------------

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 41. Write a Pandas program to check the number of rows and columns and drop
# those row if 'any' values are missing in a row of diamonds DataFrame.

# %%
print(data_df.shape)


a=data_df.dropna(how='any')
a.shape
# Out:
# (53940, 12)
# (53940, 12)

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 42. Write a Pandas program to drop a row if any or all values in a row are
# missing of diamonds DataFrame on two specific columns.

# %%
col=['carat','cut']

print(data_df[col].shape)

a=data_df[col].dropna(how='any')
a.shape
# Out:
# (53940, 2)
# (53940, 2)

# %% [markdown]
# 43. Write a Pandas program to set an existing column as the index of diamonds
# DataFrame.

# %%
a=data_df.set_index('cut')
a.head(10)
# Out:
#            Unnamed: 0  carat color clarity  depth  table  price     x     y  \
# cut
# Ideal               1   0.23     E     SI2   61.5   55.0    326  3.95  3.98
# Premium             2   0.21     E     SI1   59.8   61.0    326  3.89  3.84
# Good                3   0.23     E     VS1   56.9   65.0    327  4.05  4.07
# Premium             4   0.29     I     VS2   62.4   58.0    334  4.20  4.23
# Good                5   0.31     J     SI2   63.3   58.0    335  4.34  4.35
# Very Good           6   0.24     J    VVS2   62.8   57.0    336  3.94  3.96
# Very Good           7   0.24     I    VVS1   62.3   57.0    336  3.95  3.98
# Very Good           8   0.26     H     SI1   61.9   55.0    337  4.07  4.11
# Fair                9   0.22     E     VS2   65.1   61.0    337  3.87  3.78
# Very Good          10   0.23     H     VS1   59.4   61.0    338  4.00  4.05
#
#               z Quality–color
# cut
# Ideal      2.43      Ideal, E
# Premium    2.31    Premium, E
# Good       2.31       Good, E
# Premium    2.63    Premium, I
# Good       2.75       Good, J
# Very Good  2.48  Very Good, J
# Very Good  2.47  Very Good, I
# Very Good  2.53  Very Good, H
# Fair       2.49       Fair, E
# Very Good  2.39  Very Good, H

# %% [markdown]
# 44. Write a Pandas program to set an existing column as the index of diamonds
# DataFrame and restore the index name, and move the index back to a column.

# %%
a=data_df.set_index('cut')
a.head()
# Out:
#          Unnamed: 0  carat color clarity  depth  table  price     x     y  \
# cut
# Ideal             1   0.23     E     SI2   61.5   55.0    326  3.95  3.98
# Premium           2   0.21     E     SI1   59.8   61.0    326  3.89  3.84
# Good              3   0.23     E     VS1   56.9   65.0    327  4.05  4.07
# Premium           4   0.29     I     VS2   62.4   58.0    334  4.20  4.23
# Good              5   0.31     J     SI2   63.3   58.0    335  4.34  4.35
#
#             z Quality–color
# cut
# Ideal    2.43      Ideal, E
# Premium  2.31    Premium, E
# Good     2.31       Good, E
# Premium  2.63    Premium, I
# Good     2.75       Good, J

# %%
a.reset_index(inplace=True)
a.head()
# Out:
#        cut  Unnamed: 0  carat color clarity  depth  table  price     x     y  \
# 0    Ideal           1   0.23     E     SI2   61.5   55.0    326  3.95  3.98
# 1  Premium           2   0.21     E     SI1   59.8   61.0    326  3.89  3.84
# 2     Good           3   0.23     E     VS1   56.9   65.0    327  4.05  4.07
# 3  Premium           4   0.29     I     VS2   62.4   58.0    334  4.20  4.23
# 4     Good           5   0.31     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 45. Write a Pandas program to access a specified Series index and the Series
# values of diamonds DataFrame.

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %%
print(data_df.cut.index)
# Out:
# RangeIndex(start=0, stop=53940, step=1)

# %%
print(data_df.cut.values)
# Out:
# ['Ideal' 'Premium' 'Good' ... 'Very Good' 'Premium' 'Ideal']

# %% [markdown]
# 46. Write a Pandas program to sort a Series by its values and index of diamonds
# DataFrame.

# %%
data_df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data_df.cut.sort_values()
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %%
data_df.cut.sort_index()
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# 47. Write a Pandas program to calculate the multiply of length, width and depth
# for each cut of diamonds DataFrame.

# %%
a=data_df.copy()
a['lenght*width*depth'] = data_df.x*data_df.y*data_df.z
a.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z Quality–color  lenght*width*depth
# 0  3.98  2.43      Ideal, E           38.202030
# 1  3.84  2.31    Premium, E           34.505856
# 2  4.07  2.31       Good, E           38.076885
# 3  4.23  2.63    Premium, I           46.724580
# 4  4.35  2.75       Good, J           51.917250
# 5  3.96  2.48  Very Good, J           38.693952
# 6  3.98  2.47  Very Good, I           38.830870
# 7  4.11  2.53  Very Good, H           42.321081
# 8  3.78  2.49       Fair, E           36.425214
# 9  4.05  2.39  Very Good, H           38.718000

# %% [markdown]
# 48. Write a Pandas program to concatenate the diamonds DataFrame with the
# 'color' Series.

# %%
a=data_df.copy()
b=pd.concat([a,data_df.color],axis=1)
b.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color color
# 0  2.43      Ideal, E     E
# 1  2.31    Premium, E     E
# 2  2.31       Good, E     E
# 3  2.63    Premium, I     I
# 4  2.75       Good, J     J

# %% [markdown]
# 49. Write a Pandas program to read specified rows and all columns of diamonds
# DataFrame.

# %%
data_df.iloc[0]
# Out:
# Unnamed: 0              1
# carat                0.23
# cut                 Ideal
# color                   E
# clarity               SI2
# depth                61.5
# table                55.0
# price                 326
# x                    3.95
# y                    3.98
# z                    2.43
# Quality–color    Ideal, E
# Name: 0, dtype: object

# %% [markdown]
# 50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds
# DataFrame.

# %%
print(f"{data_df.iloc[0]}\n---------")
print(f"{data_df.iloc[5]}\n---------")
print(f"{data_df.iloc[7]}\n---------")
# Out:
# Unnamed: 0              1
# carat                0.23
# cut                 Ideal
# color                   E
# clarity               SI2
# depth                61.5
# table                55.0
# price                 326
# x                    3.95
# y                    3.98
# z                    2.43
# Quality–color    Ideal, E
# Name: 0, dtype: object
# ---------
# Unnamed: 0                  6
# carat                    0.24
# cut                 Very Good
# color                       J
# clarity                  VVS2
# depth                    62.8
# table                    57.0
# price                     336
# x                        3.94
# y                        3.96
# z                        2.48
# Quality–color    Very Good, J
# Name: 5, dtype: object
# ---------
# Unnamed: 0                  8
# carat                    0.26
# cut                 Very Good
# color                       H
# clarity                   SI1
# depth                    61.9
# table                    55.0
# price                     337
# x                        4.07
# y                        4.11
# z                        2.53
# Quality–color    Very Good, H
# Name: 7, dtype: object
# ---------

# %%
data_df.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z Quality–color
# 0  3.98  2.43      Ideal, E
# 1  3.84  2.31    Premium, E
# 2  4.07  2.31       Good, E
# 3  4.23  2.63    Premium, I
# 4  4.35  2.75       Good, J
# 5  3.96  2.48  Very Good, J
# 6  3.98  2.47  Very Good, I
# 7  4.11  2.53  Very Good, H
# 8  3.78  2.49       Fair, E
# 9  4.05  2.39  Very Good, H

# %% [markdown]
# 51. Write a Pandas program to read rows 2 through 5 and all columns of
# diamonds DataFrame.

# %%
data_df.iloc[range(1,6)]
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z Quality–color
# 1  3.84  2.31    Premium, E
# 2  4.07  2.31       Good, E
# 3  4.23  2.63    Premium, I
# 4  4.35  2.75       Good, J
# 5  3.96  2.48  Very Good, J

# %% [markdown]
# 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color'
# and 'price' of diamonds DataFrame.

# %%
data_df.loc[0:2,['color','price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color'
# through 'price' (inclusive) of diamonds DataFrame.

# %%
data_df.loc[0:2,'color':'price']
# Out:
#   color clarity  depth  table  price
# 0     E     SI2   61.5   55.0    326
# 1     E     SI1   59.8   61.0    326
# 2     E     VS1   56.9   65.0    327

# %% [markdown]
# 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column
# 'color' of diamonds DataFrame.

# %%
data_df.loc[data_df['cut']=='Premium', 'color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %%
data_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 55. Write a Pandas program to read rows in positions 0 and 1, columns in
# positions 0 and 3 of diamonds DataFrame.

# %%
#data_df.iloc[range(0,2),range(0,3)]
data_df.iloc[[0,1],[0,3]]
# Out:
#    Unnamed: 0 color
# 0           1     E
# 1           2     E

# %% [markdown]
# 56. Write a Pandas program to read rows in positions 0 through 4, columns in
# positions 1 through 4 of diamonds DataFrame.

# %%
data_df.iloc[0:5,1:5]
# Out:
#    carat      cut color clarity
# 0   0.23    Ideal     E     SI2
# 1   0.21  Premium     E     SI1
# 2   0.23     Good     E     VS1
# 3   0.29  Premium     I     VS2
# 4   0.31     Good     J     SI2

# %% [markdown]
# 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and
# all columns of diamonds DataFrame.

# %%
data_df.iloc[0:5,:]
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality–color
# 0  2.43      Ideal, E
# 1  2.31    Premium, E
# 2  2.31       Good, E
# 3  2.63    Premium, I
# 4  2.75       Good, J

# %% [markdown]
# 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in
# positions 0 through 2 (exclusive) of diamonds DataFrame.

# %%
data_df.iloc[2:6,0:3]
# Out:
#    Unnamed: 0  carat        cut
# 2           3   0.23       Good
# 3           4   0.29    Premium
# 4           5   0.31       Good
# 5           6   0.24  Very Good

# %% [markdown]
# 59. Write a Pandas program to print a concise summary of diamonds
# DataFrame.

# %% [markdown]
# 60. Write a Pandas program to get the true memory usage by diamonds
# DataFrame.

# %% [markdown]
# 61. Write a Pandas program to calculate the memory usage for each Series (in
# bytes) of diamonds DataFrame.

# %% [markdown]
# 62. Write a Pandas program to get randomly sample rows from diamonds
# DataFrame.

# %% [markdown]
# 63. Write a Pandas program to get sample 75% of the diamonds DataFrame's
# rows without replacement and store the remaining 25% of the rows in another
# DataFrame.
